# %%
import cv2
import matplotlib.pyplot as plt
from DiscSegmentation import DiscSegmentation

# %%
image_path = "../labelled_images/Caen/KOE-2428-29-OD.tif"

# %%
image = cv2.imread(image_path)
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(image)
plt.show()

# %%
segmentation = DiscSegmentation(image_path)
segmentation.show_segmentation()
